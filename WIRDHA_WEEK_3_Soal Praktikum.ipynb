# %% [markdown]
# <a href="https://colab.research.google.com/github/WirMuhSep06/Pemerograman-Dasar/blob/main/WIRDHA_WEEK_3_Soal%20Praktikum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **B.1 Soal Umum**

# %%
# Nama    : Wirdha Muhammad Septyandra
# NIM     : 4232501057
# Tanggal : 25 September 2026
# Tujuan  : Menghitung hasil operasi aritmatika dari dua bilangan bulat


x = int(input("Masukkan bilangan pertama: "))
y = int(input("Masukkan bilangan kedua: "))

print("Penjumlahan (+)      :", x + y)
print("Pengurangan (-)      :", x - y)
print("Perkalian (*)        :", x * y)
print("Pembagian (/)        :", x / y)
print("Pembagian Bulat (//) :", x // y)
print("Modulus (%)          :", x % y)
# Out:
# Masukkan bilangan pertama: 5
# Masukkan bilangan kedua: 5
# Penjumlahan (+)      : 10
# Pengurangan (-)      : 0
# Perkalian (*)        : 25
# Pembagian (/)        : 1.0
# Pembagian Bulat (//) : 1
# Modulus (%)          : 0

# %%
# Nama    : Wirdha Muhammad Septyandra
# NIM     : 4232501057
# Tanggal : 25 September 2026
# Tujuan  : Menentukan apakah nilai ujian yang diinput dinyatakan lulus


nilai = float(input("Masukkan nilai ujian (0-100): "))

lulus = nilai >= 60

print("Nilai ini termasuk kategori lulus (>= 60):", lulus)
# Out:
# Masukkan nilai ujian (0-100): 87
# Nilai ini termasuk kategori lulus (>= 60): True

# %%
# Nama    : Wirdha Muhammad Septyandra
# NIM     : 4232501057
# Tanggal : 25 September 2026
# Tujuan  : Menentukan apakah seseorang boleh mengemudi sendiri


umur = int(input("Masukkan umur: "))
input_sim = input("Apakah memiliki SIM? (True/False): ").lower() == "true"

boleh_mengemudi = umur >= 17 and input_sim
pengemudi_pemula = input_sim and (17 <= umur <= 20)

print("Boleh mengemudi sendiri:", boleh_mengemudi)
print("Kategori pengemudi pemula:", pengemudi_pemula)
# Out:
# Masukkan umur: 25
# Apakah memiliki SIM? (True/False): punya
# Boleh mengemudi sendiri: False
# Kategori pengemudi pemula: False

# %% [markdown]
# ## **B.2 Soal Konteks Energi**

# %%
# Nama    : Wirdha Muhammad Septyandra
# NIM     : 4232501057
# Tanggal : 25 September 2026
# Tujuan  : menghitung efisiensi termal sebuah unit pembangkit


energi_input = float(input("Masukkan energi input (MJ): "))
energi_output = float(input("Masukkan energi output (MJ): "))

efisiensi = (energi_output / energi_input) * 100

print(f"Efisiensi termal unit pembangkit adalah {efisiensi:.2f}%")
# Out:
# Masukkan energi input (MJ): 80
# Masukkan energi output (MJ): 50
# Efisiensi termal unit pembangkit adalah 62.50%

# %%
# Nama    : Wirdha Muhammad Septyandra
# NIM     : 4232501057
# Tanggal : 25 September 2026
# Tujuan  : Menentukan apakah unit pembangkit perlu maintenance

suhu_boiler = float(input("Masukkan suhu boiler (°C): "))
beban_operasi = float(input("Masukkan beban operasi (%): "))

perlu_maintenance = (suhu_boiler > 550) or (beban_operasi > 95)

print(f"Status indikator perlu maintenance untuk unit pembangkit ini adalah: {perlu_maintenance}.")
# Out:
# Masukkan suhu boiler (°C): 560
# Masukkan beban operasi (%): 90
# Status indikator perlu maintenance untuk unit pembangkit ini adalah: True.
