# %% [markdown]
# <a href="https://colab.research.google.com/github/WirMuhSep06/Pemerograman-Dasar/blob/main/WIRDHA_WEEK_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama = "Wirdha Muhammad Septyandra"
umur = 19
jurusan = "RPE"
semester = 3
matakuliah = "Pemerograman Dasar"
status_lulus = False

print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Wirdha Muhammad Septyandra
# 19
# RPE
# 3
# Pemerograman Dasar
# True

# %%
# Biodata Saya

nama = "Wirdha Muhammad Septyandra"
nim = 4232501057
umur = 19
jurusan = "Elektro"
prodi = "RPE"
semester = 3
matakuliah = "Pemerograman Dasar"
status_lulus = False
alamat = "mangsang, sei beduk"


print (nama)
print (nim)
print (umur)
print (jurusan)
print (prodi)
print (semester)
print (matakuliah)
print (status_lulus)
print (alamat)
# Out:
# Wirdha Muhammad Septyandra
# 4232501057
# 19
# Elektro
# RPE
# 3
# Pemerograman Dasar
# False
# mangsang, sei beduk
